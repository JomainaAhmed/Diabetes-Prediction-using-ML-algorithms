# %% [markdown]
# # <strong> Diabetes Prediction Model using different algorithms(Logistic Regression, Support Vector Machine and Naive Bayes Classifier)</strong>

# %% [markdown]
# ## <strong>Description</strong>

# %% [markdown]
# The objective is to predict whether patient has diabetes or not. The datasets consists of several medical predictor (Independent) variables and one target variable (Outcome). Predictor variables includes Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, Diabetes PedigreeFunction, Age, and Outcome (Dependent)
#
# Dataset url: https://www.kaggle.com/uciml/pima-indians-diabetes-database

# %% [markdown]
# # <strong>Dataset Attribute Description</strong>
#
# 1) Pregnancies---> The frequency of pregnancy
#
# 2) Glucose (mg/dl) ---> Plasma glucose concentration
#
# 3) BloodPressure ---> Diastolic blood pressure (mm Hg)
#
# 4) SkinThickness ---> Triceps skin fold thickness (mm)
#
# 5) Insulin ---> 2-Hour serum insulin (mu U/ml)
#
# 6) BMI ---> Body mass index (weight in kg/(height in m)^2)
#
# 7) DiabetesPedigreeFunction ---> Diabetes pedigree function
#
# 8) Age ---> Age (years)
#
# 9) Outcome ---> Class variable (0 or 1)
#
# 268 of 768 are 1
#
# 500 of 768 are 0

# %% [markdown]
# ## <strong> Step 1: Importing libraries like Numpy, Pandas, Matplotlib, Seaborn and Scikit learn (Sklearn)</strong>

# %% [markdown]
# <strong> Numpy </strong> : NumPy is a general-purpose array-processing package. It provides a high-performance multidimensional array object. It is the fundamental package for scientific computing with Python. Numerical Analysis Library
#
# <strong> Pandas: </strong> Pandas are used for data analytics and for reading datasets which is in .csv format and Data Preprocessing, Pandas are also used for data manipulation. it operations for manipulating numerical data.
#
# <strong> Matplotlib: </strong> For Charts or Plots
#
# <strong> Seaborn: </strong> for Charts or Plots built on top of Matplotlib, it is a data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# <strong> Sklearn: </strong> Scikit-learn library provides many unsupervised and supervised learning algorithms. The scikit-learn  Regression, Classification, and Data Preprocessing.

# %%
# Numpy

import numpy as np

#Pandas

import pandas as pd

#matplotlib}

import matplotlib.pyplot as plt

# Seaborn

import seaborn as sns

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## <strong> Step 2: Load the Dataset </strong>

# %%
# Load pima indians dataset

df=pd.read_csv("diabetes (1).csv")

# %% [markdown]
# ## <strong> Step 3: Exploratory Data Analysis </strong>

# %% [markdown]
# Exploratory Data Analysis (EDA), also known as Data Exploration, is a step in the Data Analysis Process, where several techniques are used to better understand the dataset being used.

# %% [raw]
# In this step, we will perform the below operations:
#
# <strong> 3.1) Understanding Your Variables </strong>
#
# 1) Head of the dataset
#
# 2) The shape of the dataset
#
# 3) List the types of columns
#
# 4) Info of the dataset
#
# 5) Summary of the dataset
#
# <strong> 3.2) Data Cleaning </strong>
#
# 1) Checking for Duplicate values
#
# 2) Checking for NULL values
#
# 3) Checking for zero values
#
# 4)Checking forg outliers

# %% [markdown]
# ## <strong> 3.1) Understanding Your Variables </strong>

# %% [markdown]
# ### <strong> 3.1.1) Head of the Dataset </strong>

# %% [markdown]
# The head () function will tell you the top records in the data set. By default, python shows you only the top 5 records.
#
# This head(n) function returns the first n rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it. By default it will show 5 rows.

# %%
# Display first five records of data 
df.head()

# %%
#Display last five records of the data 
df.tail()

# %%
# Display randomly any number of records of data 
df.sample(10)

# %% [markdown]
# ### <strong> 3.1.2) The shape of the dataset </strong>

# %% [markdown]
# This shape () function gives us the number of rows and columns of the dataset.

# %%
#Number of rows and columns
df.shape

# %% [markdown]
# No. of Rows=768
#
# No. of Columns=9

# %% [markdown]
# ### <strong> 3.1.3) List types of all columns </strong>

# %% [markdown]
# Using df.dtypes, we get the list of types of all the columns in our dataset.

# %%
#List the types of all columns

df.dtypes

# %% [markdown]
# ### <strong> 3.1.4) Info of the dataset </strong>

# %% [markdown]
# info() is used to check the Information about the data and the datatypes of each respective attribute.

# %%
#finding out if the dataset contains any null value

df.info()

# %% [markdown]
# ### <strong> 3.1.5) Summary of the dataset </strong>

# %% [markdown]
# The described method will help to see how data has been spread for numerical values. We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %%
#Statistical summary 
df.describe()

# %% [markdown]
# Observation:
#
# In the above table, the min value of columns, 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI is zero (0). It is clear that this values can't be zero. So, I am going to impute mean values of these respective columns instead of zero.

# %% [markdown]
# ## <strong> 3.2) Data Cleaning </strong>

# %% [markdown]
# ### <strong> 3.2.1) Drop the Duplicates</strong>

# %% [markdown]
# Check if any duplicate rows exist or not, if they exist, then we have to remove them from the dataframe.

# %%
#checking the shape before dropping the duplicates

df.shape

# %%
df.duplicated().sum()

# %%
df=df.drop_duplicates()

# %%
#checking the shape after dropping the duplicates

df.shape

# %% [markdown]
# As we see, the shape does not change, so we conclude that the dataset has no duplicates.

# %% [markdown]
# ### <strong> 3.2.2) Check the NULL values </strong>
#
# Using isnull.sum() function, we can see the null values present in the every column in the dataset.

# %%
#Count of null values

#check the missing values in any column

#Display the number of null values in every column in the dataset

df.isnull().sum()

# %% [markdown]
# There are no NULL values in the given dataset.

# %%
df.columns

# %% [markdown]
# ### <strong> 3.2.3) Check the no. of zero values in dataset </strong>

# %%
print('No. of zero values in Glucose: ',df[df['Glucose']==0].shape[0])
print('No. of zero values in Blood Pressure: ',df[df['BloodPressure']==0].shape[0])
print('No. of zero values in SkinThickness: ',df[df['SkinThickness']==0].shape[0])
print('No. of zero values in Insulin: ',df[df['Insulin']==0].shape[0])
print('No. of zero values in BMI: ',df[df['BMI']==0].shape[0])

# %%
#Replace no. of zero values with mean of that columns

df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean()) 
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean()) 
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean()) 
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean()) 
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

# %%
#Check the no. of zero values in dataset after replacing them with the mean value

print('No. of zero values in Glucose: ',df[df['Glucose']==0].shape[0])
print('No. of zero values in Blood Pressure: ',df[df['BloodPressure']==0].shape[0])
print('No. of zero values in SkinThickness: ',df[df['SkinThickness']==0].shape[0])
print('No. of zero values in Insulin: ',df[df['Insulin']==0].shape[0])
print('No. of zero values in BMI: ',df[df['BMI']==0].shape[0])

# %%
df.describe()

# %% [markdown]
# ### **3.2.4) Outlier Detection**

# %%
cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
len(df[cols].columns)

# %%
# plot for outliers detection
plt.figure(figsize=(10,10))
for i in range(len(df[cols].columns)):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=df[cols[i]])
    plt.title(df.columns[i])
    
plt.tight_layout()

# %%
q1 = df['Pregnancies'].quantile(0.25)
q3 = df['Pregnancies'].quantile(0.75)

# %%
q3-q1

# %%
def find_outlier(df, feature):
    print('Outlier: ' + feature)
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    Lower_Limit = q1 - limit
    Upper_Limit = q3 + limit
    print(f'Lower_Limit: {Lower_Limit}')
    print(f'Upper_Limit: {Upper_Limit}')
    print('_________________________')

# %%
# check IQR, upper limit, and lower limit for each feature

for i in df.drop(columns=['Outcome']) :
    find_outlier(df, i)

# %%
# creating outliers columns
out1 = df[df['Pregnancies'] > 13.5]
out2 = df[(df['Glucose'] < 39.0) | (df['Glucose'] > 201.0)]
out3 = df[(df['BloodPressure'] < 40) | (df['BloodPressure'] > 104)]
out4 = df[(df['SkinThickness'] < 3.341145833333332) | (df['SkinThickness'] > 49.1953125)]
out5 = df[(df['Insulin'] < 8.0) | (df['Insulin'] > 342.0)]
out6 = df[(df['BMI'] < 13.849999999999998) | (df['BMI'] > 50.25)]
out7 = df[df['DiabetesPedigreeFunction'] > 1.2]
out8 = df[df['Age'] > 66.5]

# %%
# creating outliers dataframe
out_all = pd.concat([out1, out2, out3, out4, out5, out6, out7, out8], axis = 0)
out_all.drop_duplicates(inplace=True)
out_all

# %%
#check outliers percentage
print('Percentage Outlier')
len(out_all)/len(df)*100

# %%
df.drop(labels=out_all.index, axis=0, inplace=True)

# %%
df.shape

# %% [markdown]
# # <strong> Step 4: Data Visualization </strong>

# %% [markdown]
# ### 4.1) Count plots

# %%
# outcome count plot
f,ax=plt.subplots(1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax=ax[0],shadow=True)
ax[0].set_title('Outcome') 
ax[0].set_ylabel('')
sns.countplot(x='Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome') 
N,P= df['Outcome'].value_counts()
print('Negative (0): ',N)
print('Positive (1): ',P)
plt.grid()
plt.show()

# %% [markdown]
# Out of the total of 675 people, 220 are diabetic (Positive (1)) and 455 are non-diabetics (negative (0)).
#
# In the outcome column, 1 represents diabetes positive and 0 represents diabetes negative.
#
# The countplot tells us that the dataset is imbalanced, as the number of patients who don't have diabetes is more than those who have diabetes.

# %% [markdown]
# ### 4.2) Histogram

# %% [markdown]
# Histograms are one of the most common graphs used to display numeric data.
#
# distribution of the data - Whether the data is normally distributed or if it's skewed (to the left or right)

# %%
# Histogram of each feature

df.hist(bins=10,figsize=(10,10))

plt.show()

# %% [markdown]
# ### <strong> 4.5) Analyzing relationships between variables </strong>

# %% [markdown]
# ### Correlation analysis
#
# Correlation analysis is used to quantify the degree to which two variables are related. Through the correlation analysis, you evaluate correlation coefficient that tells you how much one variable changes when the other one does. Correlation analysis provides you with a linear relationship between two variables. When we correlate feature variables with the target variable, we get to know that how much dependency is there between particular feature variables and target variable.

# %%
import seaborn as sns

# Get correlations of each feature in the dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10, 10))

# Plot heat map
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# ### Observations:
#
# From the correlation heatmap, we can see that there is a high correlation between Outcome and [Pregnancies, Glucose, BMI, Age, Blood Pressure), We can select these features to accept input from the user and predict the outcome

# %%
df.describe()

# %% [markdown]
# ## <strong> 5) Split the dataframe into X and Y </strong>

# %%
target_name = "Outcome"

#Separate object for target feature 
y=df[target_name]

#Separate Object for Input Features 
X=df.drop(target_name, axis=1)

# %%
X.head()

# %%
y.head()

# %%
print(X.shape)
print(y.shape)

# %% [markdown]
# (Rows * Columns)

# %%
Diabetic = df[df['Outcome']==1]
NonDiabetic = df[df['Outcome']==0]

# %%
print(Diabetic.shape,NonDiabetic.shape)

# %% [markdown]
# ### changing imbalanced dataset into balanced

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# Implementing Oversampling for Handling Imbalanced 
smk = SMOTETomek(random_state=7)
X_res,y_res=smk.fit_resample(X,y)

# %%
X_res.shape,y_res.shape

# %%
from collections import Counter
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_res)))

# %% [markdown]
# ## <strong> 6) Apply Feature Scaling </strong>

# %%
#Apply Standard Scaler 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaler.fit(X_res) 
SSX = scaler.transform(X_res)

# %% [markdown]
# ## <strong> 7) Train-Test-Split </strong>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(SSX, y_res, test_size=0.3, random_state=7)

# %%
X_train.shape,y_train.shape

# %%
X_test.shape,y_test.shape

# %% [markdown]
# ## <strong> 8) Applying the Classification Algorithms </strong>

# %% [markdown]
# ### <strong> 8.1) Logistic Regression </strong>

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(X_train, y_train)

# %% [markdown]
# ### <strong> 8.2) Support Vector Machine (SVM) </strong>

# %%
from sklearn.svm import SVC
sv=SVC(kernel='linear') 
sv.fit(X_train,y_train)

# %% [markdown]
# ### <strong> 8.3) Naive Bayes Classifier (SVM) </strong>

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,y_train)

# %% [markdown]
# # <strong> 9) Making Prediction </strong>

# %% [markdown]
# ### <strong> 9.1) Making prediction on test by using Logistic Regression </strong>

# %%
X_test.shape

# %%
# Make predictions on the test dataset

lr_pred = lr.predict(X_test)

# %%
lr_pred.shape

# %% [markdown]
# ### <strong> 9.2) Make prediction on test by using SVM </strong>

# %%
# Making predictions on test dataset 

sv_pred=sv.predict(X_test)

# %%
sv_pred.shape

# %% [markdown]
# ### <strong> 9.3) Make prediction on test by using Naive Bayes Classifier </strong>

# %%
# Making predictions on test dataset 

nb_pred=nb.predict(X_test)
nb_pred.shape

# %% [markdown]
# # <strong> 10) Model Evaluation </strong>

# %% [markdown]
# ### <strong> 10.1) Train Score & Test Score </strong>

# %%
# Train score & Test score of Logistic Regression
from sklearn.metrics import accuracy_score
print("Training Accuracy of Logistic Regression:", lr.score(X_train, y_train)*100)
print("Accuracy (Test) score of Logistic Regression:", accuracy_score(y_test, lr_pred) *100)

# %%
# Train score & Test score of SVM
print("Training Accuracy of SVM:", sv.score(X_train, y_train)*100)
print("Accuracy (Test) score of SVM:", accuracy_score(y_test, sv_pred) *100)

# %%
# Train score & Test score of Naive-Bayes Classifier
print("Train Accuracy of Naive-Bayes Classifier:", nb.score(X_train, y_train)*100)
print("Accuracy (Test) score of Naive-Bayes Classifier:", accuracy_score(y_test, nb_pred) *100)

# %% [markdown]
# ### <strong> 10.2) Confusion Matrix </strong>

# %% [markdown]
# Confusion metrics is a table which is used to describe the performance of a classification problem.
#
# It visualizes the accuracy of a classifier by comparing predicted values with actual values.
#
# The terms used in confusion metrics are True positive (TP), true negative (TN), false positive (FP) and false negative (FN)
#
# True Positive: The predicted result is positive, while it is labeled as positive.
#
# False Positive: The predicted result is positive, while it is labeled as negative. It calls Type | Error as well.
#
# False Negative: The predicted result is negative, while it is labeled as positive. It calls Type II Error as well.
#
# True Negative: The predicted result is negative, while it is labeled as negative.

# %% [markdown]
# <strong> 10.2.1) Confusion Matrix of Logistic Regression </strong>

# %%
from sklearn.metrics import classification_report, confusion_matrix

#confusion Motrix of Logistic Regression

cm=confusion_matrix(y_test, lr_pred)

cm

# %%
sns.heatmap(confusion_matrix(y_test,lr_pred), annot=True, fmt="d")

# %%
print("Classification Report of Logistic Regression: \n",classification_report(y_test, lr_pred,digits=4))

# %%
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0] 
TP=cm[1,1]

# %%
TN, FP, FN, TP

# %%
 # Making the Confusion Matrix Of Logistic Regression

from sklearn.metrics import classification_report, confusion_matrix

from sklearn.metrics import accuracy_score

cm=confusion_matrix(y_test, lr_pred)

print('TN True Negative: {}'.format(cm[0,0])) 
print('FP False Positive: {}'.format(cm[0,1]))
print('FN False Negative: {}'.format(cm[1,0])) 
print('IP True Positive: {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))

# %%
78.8679245283019+21.132075471698116

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0', '1']
plt.title('Confusion Matrix Of Logistic Regression')
plt.ylabel('Actual (true) values') 
plt.xlabel('Predicted values')
tick_marks = np.arange(len(classNames)) 
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(s[i][j]) + " = " + str(cm[i][j]))
plt.show()

# %%
pd.crosstab(y_test, lr_pred, margins=False)

# %%
pd.crosstab(y_test, lr_pred, margins=True)

# %%
pd.crosstab(y_test, lr_pred, rownames=['Actual values'], colnames=['Predicted values'], margins=True)

# %% [markdown]
# ### <strong> 10.2.2) Precision (PPV-Positive Predictive Value) </strong>
#
# It is the ratio of correctly predicted positive (TP) observations to the total predicted positive (TP+FP) observations.
#
# Precision = TP/(TP+FP)
#
# Where TP = True Positive and FP = False Positive

# %%
TP,FP

# %%
Precision=TP/(TP+FP) 
Precision

# %%
114/(114+25)

# %%
#print precision score

precision_Score = TP/ float(TP + FP)*100
print('Precision score : {0:0.4f}'.format(precision_Score))

# %%
from sklearn.metrics import precision_score 
print("precision Score is:", precision_score(y_test, lr_pred)*100)
print("Micro Average precision Score is:", precision_score(y_test, lr_pred, average='micro') *100)
print("Macro Average precision Score is:", precision_score(y_test,lr_pred, average='macro')*100) 
print("Weighted Average precision Score is:", precision_score(y_test, lr_pred, average='weighted')*100)
print("precision Score on Non weighted score is:", precision_score(y_test, lr_pred, average=None)*100)

# %%
print('Classification Report of Logistic Regression: \n', classification_report(y_test, lr_pred, digits=4))

# %% [markdown]
# ### <strong> 10.2.3) Recall (True Positive Rate (TPR)) </strong>
#
# It is ratio of correctly predicted positive (TP) observations to the total observations which are actually true.

# %%
recall_score = TP/ float(TP + FN)*100 
print('recall_score: ', recall_score)

# %%
TP, FN

# %%
114/(114+31)

# %%
from sklearn.metrics import recall_score

print('Recall or Sensitivity score:', recall_score(y_test, lr_pred)*100)

# %%
print("Micro Average Recall Score is:", recall_score(y_test, lr_pred, average="micro") * 100)
print("Macro Average Recall Score is:", recall_score(y_test, lr_pred, average="macro") * 100)
print("Weighted Average Recall Score is:", recall_score(y_test, lr_pred, average="weighted") * 100)
print("Recall Score on Non weighted score is:", recall_score(y_test, lr_pred, average=None) * 100)

# %% [markdown]
# ## <strong> Classification Report of Logistic Regression </strong>

# %%
from sklearn.metrics import classification_report 
print('Classification Report of Logistic Regression: \n', classification_report(y_test, lr_pred, digits=4))

# %% [markdown]
# ### <strong> False Positive Rate (FPR) </strong>

# %%
FPR=FP/ float(FP + TN)*100 
print('False Positive Rate: {0:0.4f}'.format(FPR))

# %%
FP,TN

# %%
26/(26+114)

# %% [markdown]
# ### <strong> F1-Score (FPR) </strong>

# %%
from sklearn.metrics import f1_score 
print('f1 score of macro', f1_score(y_test, lr_pred)*100)

# %%
print("Micro Average F1 Score is:", f1_score(y_test, lr_pred, average='micro')*100) 
print("Marcro Average F1 Score is:", f1_score(y_test, lr_pred,average='macro')*100) 
print("Weighted Average F1 Score is:", f1_score(y_test, lr_pred, average='weighted')*100) 
print("F1 Score on Non weighted score is:", f1_score(y_test, lr_pred, average=None) *100)

# %% [markdown]
# <strong> 10.2.1) Confusion Matrix of SVM </strong>

# %%
#confusion Matrix of SVM

cm=confusion_matrix(y_test, sv_pred)

cm

# %%
sns.heatmap(confusion_matrix(y_test,sv_pred), annot=True, fmt="d")

# %%
print("Classification Report of SVM: \n",classification_report(y_test, sv_pred,digits=4))

# %%
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0] 
TP=cm[1,1]

# %%
TN, FP, FN, TP

# %%
 # Making the Confusion Matrix Of SVM

cm=confusion_matrix(y_test, sv_pred)

print('IN True Negative: {}'.format(cm[0,0])) 
print('FP False Positive: {}'.format(cm[0,1]))
print('FN False Negative: {}'.format(cm[1,0])) 
print('IP True Positive: {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))

# %%
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0', '1']
plt.title('Confusion Matrix Of SVM')
plt.ylabel('Actual (true) values') 
plt.xlabel('Predicted values')
tick_marks = np.arange(len(classNames)) 
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(s[i][j]) + " = " + str(cm[i][j]))
plt.show()

# %%
pd.crosstab(y_test, sv_pred, margins=False)

# %%
pd.crosstab(y_test, sv_pred, margins=True)

# %%
pd.crosstab(y_test, sv_pred, rownames=['Actual values'], colnames=['Predicted values'], margins=True)

# %% [markdown]
# ### <strong> 10.2.2) Precision (PPV-Positive Predictive Value) </strong>

# %%
TP,FP

# %%
Precision=TP/(TP+FP) 
Precision

# %%
104/(104+24)

# %%
#print precision score

precision_Score = TP/ float(TP + FP)*100
print('Precision score : {0:0.4f}'.format(precision_Score))

# %%
print("precision Score is:", precision_score(y_test, sv_pred)*100)
print("Micro Average precision Score is:", precision_score(y_test, sv_pred, average='micro') *100)
print("Macro Average precision Score is:", precision_score(y_test, sv_pred, average='macro')*100) 
print("Weighted Average precision Score is:", precision_score(y_test, sv_pred, average='weighted')*100)
print("precision Score on Non weighted score is:", precision_score(y_test, sv_pred, average=None)*100)

# %%
print('Classification Report of SVM: \n', classification_report(y_test, sv_pred, digits=4))

# %% [markdown]
# ### <strong> 10.2.3) Recall (True Positive Rate (TPR)) </strong>

# %%
recall_score = TP/ float(TP + FN)*100 
print('recall_score: ', recall_score)

# %%
TP, FN

# %%
104/(104+30)

# %%
from sklearn.metrics import recall_score

print('Recall or Sensitivity score:', recall_score(y_test, sv_pred)*100)

# %%
print("Micro Average Recall Score is:", recall_score(y_test, sv_pred, average="micro") * 100)
print("Macro Average Recall Score is:", recall_score(y_test, sv_pred, average="macro") * 100)
print("Weighted Average Recall Score is:", recall_score(y_test, sv_pred, average="weighted") * 100)
print("Recall Score on Non weighted score is:", recall_score(y_test, sv_pred, average=None) * 100)

# %% [markdown]
# ## <strong> Classification Report of SVM </strong>

# %%
from sklearn.metrics import classification_report 
print('Classification Report of SVM: \n', classification_report(y_test, sv_pred, digits=4))

# %% [markdown]
# ### <strong> False Positive Rate (FPR) </strong>

# %%
FPR=FP/ float(FP + TN)*100 
print('False Positive Rate: {0:0.4f}'.format(FPR))

# %%
FP, TN

# %%
24/(24+116)

# %% [markdown]
# ### <strong> F1- Score </strong>

# %%
from sklearn.metrics import f1_score 
print('f1 score of macro :', f1_score(y_test, sv_pred)*100)

# %%
print("Micro Average F1 Score is:", f1_score(y_test, sv_pred, average='micro')*100) 
print("Marcro Average F1 Score is:", f1_score(y_test, sv_pred,average='macro')*100) 
print("Weighted Average F1 Score is:", f1_score(y_test, sv_pred, average='weighted')*100) 
print("F1 Score on Non weighted score is:", f1_score(y_test, sv_pred, average=None) *100)

# %% [markdown]
# <strong> 10.2.1) Confusion Matrix of Naive Bayes Classifier </strong>

# %%
from sklearn.metrics import classification_report, confusion_matrix

#confusion Matrix of Naive Bayes Classifier

cm=confusion_matrix(y_test, nb_pred)

cm

# %%
sns.heatmap(confusion_matrix(y_test,nb_pred), annot=True, fmt="d")

# %%
print("Classification Report of Naive Bayes Classifier: \n",classification_report(y_test, nb_pred,digits=4))

# %%
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0] 
TP=cm[1,1]

# %%
TN, FP, FN, TP

# %%
 # Making the Confusion Matrix Of Naive Bayes Classifier

cm=confusion_matrix(y_test, nb_pred)

print('TN True Negative: {}'.format(cm[0,0])) 
print('FP False Positive: {}'.format(cm[0,1]))
print('FN False Negative: {}'.format(cm[1,0])) 
print('IP True Positive: {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))

# %%
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0', '1']
plt.title('Confusion Matrix Of Naive Bayes Classifier')
plt.ylabel('Actual (true) values') 
plt.xlabel('Predicted values')
tick_marks = np.arange(len(classNames)) 
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(s[i][j]) + " = " + str(cm[i][j]))
plt.show()

# %%
pd.crosstab(y_test, nb_pred, margins=False)

# %%
pd.crosstab(y_test, nb_pred, margins=True)

# %%
pd.crosstab(y_test, nb_pred, rownames=['Actual values'], colnames=['Predicted values'], margins=True)

# %% [markdown]
# ### <strong> 10.2.2) Precision (PPV-Positive Predictive Value) </strong>

# %%
TP,FP

# %%
Precision=TP/(TP+FP) 
Precision

# %%
90/(90+27)

# %%
#print precision score

precision_Score = TP/ float(TP + FP)*100
print('Precision score : {0:0.4f}'.format(precision_Score))

# %%
print("precision Score is:", precision_score(y_test, nb_pred)*100)
print("Micro Average precision Score is:", precision_score(y_test, nb_pred, average='micro') *100)
print("Macro Average precision Score is:", precision_score(y_test, nb_pred, average='macro')*100) 
print("Weighted Average precision Score is:", precision_score(y_test, nb_pred, average='weighted')*100)
print("precision Score on Non weighted score is:", precision_score(y_test, nb_pred, average=None)*100)

# %%
print('Classification Report of NB: \n', classification_report(y_test, nb_pred, digits=4))

# %% [markdown]
# ### <strong> 10.2.3) Recall (True Positive Rate (TPR)) </strong>

# %%
recall_score = TP/ float(TP + FN)*100 
print('recall_score: ', recall_score)

# %%
TP, FN

# %%
53/(53+31)

# %%
from sklearn.metrics import recall_score

print('Recall or Sensitivity score:', recall_score(y_test, nb_pred)*100)

# %%
print("Micro Average Recall Score is:", recall_score(y_test, nb_pred, average="micro") * 100)
print("Macro Average Recall Score is:", recall_score(y_test, nb_pred, average="macro") * 100)
print("Weighted Average Recall Score is:", recall_score(y_test, nb_pred, average="weighted") * 100)
print("Recall Score on Non weighted score is:", recall_score(y_test, nb_pred, average=None) * 100)

# %% [markdown]
# ## <strong> Classification Report of Naive Bayes Classifier </strong>

# %%
from sklearn.metrics import classification_report 
print('Classification Report of NB: \n', classification_report(y_test, nb_pred, digits=4))

# %% [markdown]
# ### <strong> False Positive Rate (FPR) </strong>

# %%
FPR = FP/ float(FP + TN)*100
print('False Positive Rate: {0:0.4f}'.format(FPR))

# %%
FP, TN

# %%
27/(27+113)

# %% [markdown]
# # <strong> F1 - Score </strong>

# %%
from sklearn.metrics import f1_score 
print('f1 score of macro :', f1_score(y_test, nb_pred)*100)

# %%
print("Micro Average F1 Score is:", f1_score(y_test, nb_pred, average='micro')*100) 
print("Marcro Average F1 Score is:", f1_score(y_test, nb_pred,average='macro')*100) 
print("Weighted Average F1 Score is:", f1_score(y_test, nb_pred, average='weighted')*100) 
print("F1 Score on Non weighted score is:", f1_score(y_test, nb_pred, average=None) *100)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Hyperparameter Tuning

# %%
param_grid1 = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'saga', 'newton-cg', 'lbfgs'],
    'max_iter': [100, 200, 1000],
    'class_weight': ['balanced', None],
    'multi_class': ['auto', 'ovr', 'multinomial']
}

# %%
grid_search1 = GridSearchCV(lr, param_grid1, cv=5, scoring='accuracy')
grid_search1.fit(X_train, y_train)

# %%
best_model1 = grid_search1.best_estimator_
y_pred1 = best_model1.predict(X_test)
accuracy1 = accuracy_score(y_test, y_pred1)
precision1 = precision_score(y_test, y_pred1)
print(f"Test Accuracy of LR: {accuracy1}")
print(f"Precision of LR: {precision1}")

# %%
best_hyperparams1 = grid_search1.best_params_
print(f"Best Hyperparameters for LR: {best_hyperparams1}")

# %%
param_grid2 = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto', 0.1, 1],
    'class_weight': ['balanced', None]
}

# %%
grid_search2 = GridSearchCV(sv, param_grid2, cv=5, scoring='accuracy')
grid_search2.fit(X_train, y_train)

# %%
best_model2 = grid_search2.best_estimator_
y_pred2 = best_model2.predict(X_test)
accuracy2 = accuracy_score(y_test, y_pred2)
precision2 = precision_score(y_test, y_pred2)
print(f"Test Accuracy of SVM: {accuracy2}")
print(f"Precision of SVM: {precision2}")

# %%
best_hyperparams2 = grid_search2.best_params_
print(f"Best Hyperparameters for SVM: {best_hyperparams2}")

# %%
param_grid3 = {
    'priors': [None, [0.1, 0.9], [0.2, 0.8], [0.3, 0.7], [0.4, 0.6], [0.5, 0.5]]
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6]
}

# %%
grid_search3 = GridSearchCV(nb, param_grid3, cv=5, scoring='accuracy')
grid_search3.fit(X_train, y_train)

# %%
best_model3 = grid_search3.best_estimator_
y_pred3 = best_model3.predict(X_test)
accuracy3 = accuracy_score(y_test, y_pred3)
precision3 = precision_score(y_test, y_pred3)
print(f"Test Accuracy of NB: {accuracy3}")
print(f"Precision of NB: {precision3}")

# %%
best_hyperparams3 = grid_search3.best_params_
print(f"Best Hyperparameters for NB: {best_hyperparams3}")

# %%
comparison_df = pd.DataFrame({
    'Metric': ['Precision', 'Accuracy'],
    'Before Tuning': [precision_score(y_test, lr_pred), accuracy_score(y_test, lr_pred)],
    'After Tuning': [precision1, accuracy1]
})

# Display the comparison table
print("\nComparison of Precision and Accuracy before and after Hyperparameter Tuning for Logistic Regression:")
print(comparison_df)

# %%
comparison_df = pd.DataFrame({
    'Metric': ['Precision', 'Accuracy'],
    'Before Tuning': [precision_score(y_test, sv_pred), accuracy_score(y_test, sv_pred)],
    'After Tuning': [precision2, accuracy2]
})

# Display the comparison table
print("\nComparison of Precision and Accuracy before and after Hyperparameter Tuning for Support Vector Machine:")
print(comparison_df)

# %%
comparison_df = pd.DataFrame({
    'Metric': ['Precision', 'Accuracy'],
    'Before Tuning': [precision_score(y_test, nb_pred), accuracy_score(y_test, nb_pred)],
    'After Tuning': [precision3, accuracy3]
})

# Display the comparison table
print("\nComparison of Precision and Accuracy before and after Hyperparameter Tuning for Naive Bayes:")
print(comparison_df)

# %% [markdown]
# # <strong> Making a Predictive System </strong>

# %%
#Prediction

from sklearn.linear_model import LogisticRegression

# %%
X = df.drop('Outcome',axis=1)
y = df['Outcome']

# %%
lr = LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
lr.fit(X,y)

# %%
#Prediction on New Data
new_data = pd.DataFrame({
    'Pregnancies':7,
    'Glucose':100,
    'BloodPressure':68,
    'SkinThickness':39,
    'Insulin':304,
    'BMI':37.7,
    'DiabetesPedigreeFunction':0.254,
    'Age':41,      
},index=[0])

# %%
p = lr.predict(new_data)

# %%
if p[0] == 0:
    print('Person is non-diabetic')
else:
    print('Person is diabetic')
